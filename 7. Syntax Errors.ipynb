# %% [markdown]
# ### Error Handling (Error and Exception Handling)
# Two types of error by occurrence:
# 1. Syntax error (syntax error)
# 2. Exceptions (exceptions)

# %% [markdown]
# ### Syntax Error

# %%
#error sintaksis indentasi 
for i in "data":
print(i)
# Out:
#   File "<ipython-input-3-1e1450808eb9>", line 2
#     print(i)
#         ^
# IndentationError: expected an indented block

# %%
#error sintaksis titik dua
for i in "data"
  print(i)
# Out:
#   File "<ipython-input-5-bc0f59f405a2>", line 2
#     for i in "data"
#                    ^
# SyntaxError: invalid syntax

# %%
pembagi = 7
for i in range(2,6):
if i == 21/pembagi:
    print(i)
# Out:
#   File "<ipython-input-7-03ef859ac45b>", line 3
#     if i == 21/pembagi:
#      ^
# IndentationError: expected an indented block

# %%
pembagi = 7
for i in range(2,6):
  if i == 21/pembagi
    print(i)
# Out:
#   File "<ipython-input-8-f2b7b11eac9c>", line 3
#     if i == 21/pembagi
#                       ^
# SyntaxError: invalid syntax

# %%
a = float(input('Enter a number: '))
b = float(input('Enter a number: '))

c = a+b/2
print(c)
# Out:
# Enter a number: 5
# Enter a number: 6
# 8.0
