# %% [markdown]
# ### Exceptions
# - Even if we have written a statement or expression from Python correctly, there is a possibility that an error will occur when the command is executed
# - Errors that occur while the process is in progress are called exceptions and can be fatal if not handled
# Most exceptions in Python are not handled by the application, so the application crashes and an error message appears
#
# For example, we forgot to assign a value to a variable, but we directly call the variable

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dbd883db58b7> in <module>()
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %% [markdown]
# For example, string variables are operated with variable number

# %%
number = "1"

# %%
number + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-88a0caa09669> in <module>()
# ----> 1 number + 2
#
# TypeError: can only concatenate str (not "int") to str
